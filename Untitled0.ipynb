# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Conformer-main
# Out:
# /content/drive/MyDrive/Conformer-main

# %%
# !pip install torch


# !pip install timm


# !pip install torchvision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.6 MB/s eta 0:00:00
# ...

# %%
# !python main.py \
# --model Conformer_small_patch16\
#  --data-set IMNET\
#   --batch-size 16\
#    --lr 0.0001\
#     --num_workers 8\
#      --data-path Data\
#       --output_dir $./output/Conformer_small_patch16_batch_1024_lr1e-3_300epochs\
#        --epochs 2

# %%
# !python main.py  --model Conformer_small_patch16 --eval --batch-size 4000 --input-size 224 --data-set IMNET --num_workers 2 --data-path Data --resume $./output/Conformer_small_patch16_batch_1024_lr1e-3_300epochs/checkpoint.pth
# Out:
# Not using distributed mode
# ...

# %%
# !cat /usr/local/cuda/include/cudnn_version.h | grep CUDNN_MAJOR -A 2
# Out:
# cat: /usr/local/cuda/include/cudnn_version.h: No such file or directory
